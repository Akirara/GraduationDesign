# %%
import pandas as pd

# %%
adult = pd.read_csv("../data/adult.csv", header=None)

# %%
adult['label'] = adult[14].apply(lambda x: 1 if x == " <=50K" else 0)

# %%
adult
# Out:
#       0                  1       2              3     4  \
# 0    39          State-gov   77516      Bachelors  13.0
# 1    50   Self-emp-not-inc   83311      Bachelors  13.0
# 2    38            Private  215646        HS-grad   9.0
# 3    53            Private  234721           11th   7.0
# 4    28            Private  338409      Bachelors  13.0
# 5    37            Private  284582        Masters  14.0
# 6    49            Private  160187            9th   5.0
# 7    52   Self-emp-not-inc  209642        HS-grad   9.0
# 8    31            Private   45781        Masters  14.0
# 9    42            Private  159449      Bachelors  13.0
# 10   37            Private  280464   Some-college  10.0
# 11   30          State-gov  141297      Bachelors  13.0
# 12   23            Private  122272      Bachelors  13.0
# 13   32            Private  205019     Assoc-acdm  12.0
# 14   40            Private  121772      Assoc-voc  11.0
# 15   34            Private  245487        7th-8th   4.0
# ...

# %%
adult = adult.dropna(axis=0, how='any')
data = adult.drop([14, 'label'], axis=1)
label = adult['label']

# %%
data = pd.get_dummies(data)

# %%
data.columns
# Out:
# Index([                         0,                          2,
#                                 4,                         10,
#                                11,                         12,
#                            '1_ ?',           '1_ Federal-gov',
#                    '1_ Local-gov',               '1_ Private',
#                 '1_ Self-emp-inc',      '1_ Self-emp-not-inc',
#                    '1_ State-gov',                  '3_ 10th',
#                         '3_ 11th',                  '3_ 12th',
#                      '3_ 1st-4th',               '3_ 5th-6th',
#                      '3_ 7th-8th',                   '3_ 9th',
#                   '3_ Assoc-acdm',             '3_ Assoc-voc',
#                    '3_ Bachelors',             '3_ Doctorate',
#                      '3_ HS-grad',               '3_ Masters',
#                    '3_ Preschool',           '3_ Prof-school',
#                 '3_ Some-college',              '5_ Divorced',
# ...

# %%
train = data[0:420]
train_label = label[0:420]
test = data[420:]
test_label = label[420:]

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(train, train_label)
lr.score(test, test_label)
# Out:
# 0.79710144927536231

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbdt = GradientBoostingClassifier()
gbdt.fit(train, train_label)
gbdt.score(test, test_label)
# Out:
# 0.88405797101449279

# %%
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier()
mlp.fit(train, train_label)
mlp.score(test, test_label)
# Out:
# 0.81159420289855078

# %%
from xgboost.sklearn import XGBClassifier
xgb = XGBClassifier()
xgb.fit(train, train_label)
xgb.score(test, test_label)
# Out:
# 0.89855072463768115
